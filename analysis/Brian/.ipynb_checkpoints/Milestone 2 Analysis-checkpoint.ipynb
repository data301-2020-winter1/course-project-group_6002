# %% [markdown]
# # Milestone 2 analysis
# ## EAD Modules are located at the bottom of the notebook

# %% [markdown]
# # Task 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stsc

# %%
df = pd.read_csv("../../data/raw/Video_game_sales_db.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df2019 = pd.read_csv("../../data/raw/vgsales-12-4-2019.csv")
df2019
# Out:
#         Rank                           Name                      basename  \
# 0          1                     Wii Sports                    wii-sports
# 1          2              Super Mario Bros.              super-mario-bros
# 2          3                 Mario Kart Wii                mario-kart-wii
# 3          4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4          5              Wii Sports Resort             wii-sports-resort
# ...      ...                            ...                           ...
# 55787  55788                    Indivisible                   indivisible
# 55788  55789                     Lost Ember                    lost-amber
# 55789  55790                     Lost Ember                    lost-amber
# 55790  55791                     Lost Ember                    lost-amber
# 55791  55792                     Falcon Age                    falcon-age
#
#                   Genre ESRB_Rating Platform         Publisher  \
# 0                Sports           E      Wii          Nintendo
# 1              Platform         NaN      NES          Nintendo
# 2                Racing           E      Wii          Nintendo
# 3               Shooter         NaN       PC  PUBG Corporation
# 4                Sports           E      Wii          Nintendo
# ...                 ...         ...      ...               ...
# 55787      Role-Playing         NaN       PC         505 Games
# 55788         Adventure          RP       PC   Mooneye Studios
# 55789         Adventure          RP      PS4   Mooneye Studios
# 55790         Adventure          RP     XOne   Mooneye Studios
# 55791  Action-Adventure         NaN      PS4           Unknown
#
#               Developer  VGChartz_Score  Critic_Score  ...  NA_Sales  \
# 0          Nintendo EAD             NaN           7.7  ...       NaN
# 1          Nintendo EAD             NaN          10.0  ...       NaN
# 2          Nintendo EAD             NaN           8.2  ...       NaN
# 3      PUBG Corporation             NaN           NaN  ...       NaN
# 4          Nintendo EAD             NaN           8.0  ...       NaN
# ...                 ...             ...           ...  ...       ...
# 55787    Lab Zero Games             NaN           NaN  ...       NaN
# 55788   Mooneye Studios             NaN           NaN  ...       NaN
# 55789   Mooneye Studios             NaN           NaN  ...       NaN
# 55790   Mooneye Studios             NaN           NaN  ...       NaN
# 55791   Outerloop Games             NaN           NaN  ...       NaN
#
#        PAL_Sales  JP_Sales  Other_Sales    Year  Last_Update  \
# 0            NaN       NaN          NaN  2006.0          NaN
# 1            NaN       NaN          NaN  1985.0          NaN
# 2            NaN       NaN          NaN  2008.0  11th Apr 18
# 3            NaN       NaN          NaN  2017.0  13th Nov 18
# 4            NaN       NaN          NaN  2009.0          NaN
# ...          ...       ...          ...     ...          ...
# 55787        NaN       NaN          NaN  2019.0  11th Apr 19
# 55788        NaN       NaN          NaN  2019.0  11th Apr 19
# 55789        NaN       NaN          NaN  2019.0  11th Apr 19
# 55790        NaN       NaN          NaN  2019.0  11th Apr 19
# 55791        NaN       NaN          NaN     NaN  12th Apr 19
#
#                                                      url  status  \
# 0      http://www.vgchartz.com/game/2667/wii-sports/?...       1
# 1      http://www.vgchartz.com/game/6455/super-mario-...       1
# 2      http://www.vgchartz.com/game/6968/mario-kart-w...       1
# 3      http://www.vgchartz.com/game/215988/playerunkn...       1
# 4      http://www.vgchartz.com/game/24656/wii-sports-...       1
# ...                                                  ...     ...
# 55787  http://www.vgchartz.com/game/224682/indivisibl...       1
# 55788  http://www.vgchartz.com/games/game.php?id=2246...       1
# 55789  http://www.vgchartz.com/game/224690/lost-ember...       1
# 55790  http://www.vgchartz.com/game/224688/lost-ember...       1
# 55791  http://www.vgchartz.com/game/224692/falcon-age...       1
#
#       Vgchartzscore                                        img_url
# 0               NaN  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1               NaN                   /games/boxart/8972270ccc.jpg
# 2               8.7  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3               NaN  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4               8.8  /games/boxart/full_7295041AmericaFrontccc.jpg
# ...             ...                                            ...
# 55787           NaN  /games/boxart/full_6339426AmericaFrontccc.jpg
# 55788           NaN  /games/boxart/full_8893129AmericaFrontccc.jpg
# 55789           NaN  /games/boxart/full_6514293AmericaFrontccc.jpg
# 55790           NaN  /games/boxart/full_6799693AmericaFrontccc.jpg
# 55791           NaN                      /games/boxart/default.jpg
#
# [55792 rows x 23 columns]

# %%
df2019.describe().T
# Out:
#                   count          mean           std      min       25%  \
# Rank            55792.0  27896.500000  16105.907446     1.00  13948.75
# VGChartz_Score      0.0           NaN           NaN      NaN       NaN
# Critic_Score     6536.0      7.213709      1.454079     1.00      6.40
# User_Score        335.0      8.253433      1.401489     2.00      7.80
# Total_Shipped    1827.0      1.887258      4.195693     0.03      0.20
# Global_Sales    19415.0      0.365503      0.833022     0.00      0.03
# NA_Sales        12964.0      0.275541      0.512809     0.00      0.05
# PAL_Sales       13189.0      0.155263      0.399257     0.00      0.01
# JP_Sales         7043.0      0.110402      0.184673     0.00      0.02
# Other_Sales     15522.0      0.044719      0.129554     0.00      0.00
# Year            54813.0   2005.659095      8.355585  1970.00   2000.00
# status          55792.0      1.000000      0.000000     1.00      1.00
# Vgchartzscore     799.0      7.425907      1.384226     2.60      6.80
#
#                      50%       75%       max
# Rank            27896.50  41844.25  55792.00
# VGChartz_Score       NaN       NaN       NaN
# Critic_Score        7.50      8.30     10.00
# User_Score          8.50      9.10     10.00
# Total_Shipped       0.59      1.80     82.86
# Global_Sales        0.12      0.36     20.32
# NA_Sales            0.12      0.29      9.76
# PAL_Sales           0.04      0.14      9.85
# JP_Sales            0.05      0.12      2.69
# Other_Sales         0.01      0.04      3.12
# Year             2008.00   2011.00   2020.00
# status              1.00      1.00      1.00
# Vgchartzscore       7.80      8.50      9.60

# %%
df.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16327.0  2006.406443     5.828981  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %% [markdown]
# ---

# %%
"""
dfNa = pd.read_csv("../../data/raw/Video_game_sales_db.csv",
                  usecols = ["Rank", "Name", "Genre", "NA_Sales", "Year", "Platform"])
No longer in use as method chains
"""
# Out:
# '\ndfNa = pd.read_csv("../../data/raw/Video_game_sales_db.csv",\n                  usecols = ["Rank", "Name", "Genre", "NA_Sales", "Year", "Platform"])\nNo longer in use as method chains\n'

# %%
"""dfNa.dropna(axis = 1)
dfNa.reset_index(drop=True)
"""
# Out:
# 'dfNa.dropna(axis = 1)\ndfNa.reset_index(drop=True)\n'

# %%
dfWii = (
    pd.read_csv("../../data/raw/Video_game_sales_db.csv",
    usecols = ["Rank", "Name", "Genre", "Global_Sales", "Year", "Platform"])
    .loc[lambda x: x["Platform"] == "Wii"] # We love Wii only wanna play Wii
    .loc[lambda x: x["Year"] >= 2000] # Check for only recent games 
    .loc[lambda x: x["Rank"] <= 2500] # Nothing ranked lower tan 2500
    .sort_values(by= "Global_Sales", ascending = False) # Cash money check
    .assign(Averaged_Sales = lambda x: x["Global_Sales"]/4) # Average out sales
    .reset_index(drop = True)
)
dfWii

# NO outlier precautions are taken here yet
# Out:
#      Rank                               Name Platform    Year       Genre  \
# 0       1                         Wii Sports      Wii  2006.0      Sports
# 1       3                     Mario Kart Wii      Wii  2008.0      Racing
# 2       4                  Wii Sports Resort      Wii  2009.0      Sports
# 3       8                           Wii Play      Wii  2006.0        Misc
# 4       9          New Super Mario Bros. Wii      Wii  2009.0    Platform
# ..    ...                                ...      ...     ...         ...
# 194  2440  Blazing Angels: Squadrons of WWII      Wii  2007.0  Simulation
# 195  2452            Karaoke Revolution Glee      Wii  2010.0        Misc
# 196  2467  Harvest Moon: Tree of Tranquility      Wii  2007.0  Simulation
# 197  2482         WWE SmackDown vs. Raw 2009      Wii  2008.0    Fighting
# 198  2497                 The Price is Right      Wii  2008.0        Misc
#
#      Global_Sales  Averaged_Sales
# 0           82.74         20.6850
# 1           35.82          8.9550
# 2           33.00          8.2500
# 3           29.02          7.2550
# 4           28.62          7.1550
# ..            ...             ...
# 194          0.85          0.2125
# 195          0.85          0.2125
# 196          0.84          0.2100
# 197          0.83          0.2075
# 198          0.83          0.2075
#
# [199 rows x 7 columns]

# %%
dfWii.describe().T
# Out:
#                 count         mean         std        min        25%  \
# Rank            199.0  1290.010050  765.080137     1.0000   678.0000
# Year            199.0  2008.713568    1.697701  2006.0000  2007.0000
# Global_Sales    199.0     3.355829    7.561612     0.8300     1.0300
# Averaged_Sales  199.0     0.838957    1.890403     0.2075     0.2575
#
#                       50%       75%       max
# Rank            1296.0000  2021.000  2497.000
# Year            2008.0000  2010.000  2015.000
# Global_Sales       1.4700     2.340    82.740
# Averaged_Sales     0.3675     0.585    20.685

# %%
# Setting the styles of the graphs following
sns.set_style("dark")
sns.set_theme(font_scale = 1, color_codes = True)

# %%
# Investigating Wii average sales per genre after year 2000, only running with games 
# ranked higher than 2500
# this to display the box plot
plt.figure(figsize=(12, 12))
sns.boxplot(data = dfWii, x = "Averaged_Sales", y = "Genre", whis = 1.5)
# swarm plot to display the datapoints over the box plot
sns.stripplot(data = dfWii, x = "Averaged_Sales", y = "Genre", color = "0.25")
# Out:
# <AxesSubplot:xlabel='Averaged_Sales', ylabel='Genre'>

# %% [markdown]
# # Outlier precautions taken here
# Might not be perfect, but we took some measure of removing high and low outliers arbituary

# %%
dfClean = (
        pd.read_csv("../../data/raw/Video_game_sales_db.csv",
        usecols = ["Rank", "Name", "Genre", "Global_Sales", "Year", "Platform"]) # So far our only focus of work
        .sort_values(by= "Global_Sales", ascending = False) # Cash money check
        .dropna(axis = 1) # Drop any NA values completely
        .reset_index(drop=True) # Reset index so we don't mess up orders
    )
dfClean
# Out:
#         Rank                                  Name Platform         Genre  \
# 0          1                            Wii Sports      Wii        Sports
# 1          2                     Super Mario Bros.      NES      Platform
# 2          3                        Mario Kart Wii      Wii        Racing
# 3          4                     Wii Sports Resort      Wii        Sports
# 4          5              Pokemon Red/Pokemon Blue       GB  Role-Playing
# ...      ...                                   ...      ...           ...
# 16593  16189                           BattleForge       PC      Strategy
# 16594  16190                        Jewel Quest II       PC        Puzzle
# 16595  16191                      Toro to Morimori      PS3          Misc
# 16596  16192  Sonic & All-Stars Racing Transformed       PC        Racing
# 16597  16600                      Spirits & Spells      GBA      Platform
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 5 columns]

# %%
def load_and_process_Wii(filePath):

    dfClean = (
        pd.read_csv(filePath,
        usecols = ["Rank", "Name", "Genre", "Global_Sales", "Year", "Platform"]) # So far our only focus of work
        .sort_values(by = "Global_Sales", ascending = False) # Cash money check
        .dropna(axis = 0, thresh = 3) # Drop any NA values completely
        .loc[lambda x: x["Global_Sales"].between(5, 90.00)] # Remove the overkill outlier Wii sport saes at 80
        .reset_index(drop=True) # Reset index so we don't mess up orders
    )
    
    dfWii = (
        dfClean
        .loc[lambda x: x["Platform"] == "Wii"] # We love Wii only wanna play Wii
        .loc[lambda x: x["Year"] >= 2000] # Check for only recent games
        .loc[lambda x: x["Rank"] <= 2500] # Nothing ranked lower tan 2500
        .assign(Averaged_Sales = lambda x: x["Global_Sales"]/stsc.median(dfClean["Global_Sales"])) # Average out sales
        .sort_values(by= "Global_Sales", ascending = False) # Re-sort in case any vales got changed
        .reset_index(drop = True) # Order things nicely
    )
    return dfWii

# %%
dfWiiN = load_and_process_Wii("../../data/raw/Video_game_sales_db.csv")
dfWiiN.head(5)
# Out:
#    Rank                       Name Platform    Year     Genre  Global_Sales  \
# 0     1                 Wii Sports      Wii  2006.0    Sports         82.74
# 1     3             Mario Kart Wii      Wii  2008.0    Racing         35.82
# 2     4          Wii Sports Resort      Wii  2009.0    Sports         33.00
# 3     8                   Wii Play      Wii  2006.0      Misc         29.02
# 4     9  New Super Mario Bros. Wii      Wii  2009.0  Platform         28.62
#
#    Averaged_Sales
# 0       11.443983
# 1        4.954357
# 2        4.564315
# 3        4.013831
# 4        3.958506

# %%
# Investigating Wii average sales per genre after year 2000, only running with games 
# ranked higher than 2500
# this to display the box plot
plt.figure(figsize=(12, 12))
sns.boxplot(data = dfWiiN, x = "Averaged_Sales", y = "Genre", whis = 1.5)
# swarm plot to display the datapoints over the box plot
sns.stripplot(data = dfWiiN, x = "Averaged_Sales", y = "Genre", color = "0.25")
# Out:
# <AxesSubplot:xlabel='Averaged_Sales', ylabel='Genre'>

# %%
# Testing out a correlation and heatup 
wiiN = dfWiiN.corr()
sns.heatmap(wiiN, xticklabels=wiiN.columns, yticklabels=wiiN.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dfWiiN)

# %% [markdown]
# ### Will have to resolve the issue of representing sales while dealing with certain too good selling Nintendo titles

# %% [markdown]
# ## Starting analysis round 2 of Nintendo sales over the years

# %%
def load_and_process_Nintendo(filePath):
    import pandas as pd
    dfClean = (
        pd.read_csv(filePath,
        usecols = ["Rank", "Name", "Publisher", "Platform", "Genre", "Global_Sales", "Year"]) # So far our only focus of work
        .sort_values(by= "Global_Sales", ascending = False) # Cash money check
        .dropna(axis = 0, thresh = 3) # Drop any NA values completely
        .loc[lambda x: x["Global_Sales"].between(5, 90.00)] # Remove the overkill outlier Wii sport saes at 80
        #Excessive low number sales mess up our median so we are removing it for now by specifying values between 5-90
        .reset_index(drop=True) # Reset index so we don't mess up orders
    )

   # print(stsc.median(dfClean["Global_Sales"]))
   # print(stsc.mean(dfClean["Global_Sales"]))

    dfWii = (
        dfClean
        .loc[(dfClean["Publisher"] == "Nintendo")]
        #.loc[(dfClean["Platform"] == "Wii") | (dfClean["Platform"] == "DS")]
        .loc[lambda x: x["Year"] >= 2000] # Check for only recent games
        .loc[lambda x: x["Rank"] <= 2500] # Nothing ranked lower tan 2500
        .assign(median = stsc.median(dfClean["Global_Sales"]))
        .assign(Averaged_Sales = lambda x: x["Global_Sales"]/stsc.median(dfClean["Global_Sales"])) #Putting the sales number over its median to try and mitigate issues from the outliers
        .sort_values(by= "Global_Sales", ascending = False) # Re-sort in case any vales got changed
        .reset_index(drop = True) # Order things nicely
    )
    return dfWii

# %%
dfNin = load_and_process_Nintendo("../../data/raw/Video_game_sales_db.csv")
dfNin.head(5)
# Out:
#    Rank                   Name Platform    Year     Genre Publisher  \
# 0     1             Wii Sports      Wii  2006.0    Sports  Nintendo
# 1     3         Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 2     4      Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 3     7  New Super Mario Bros.       DS  2006.0  Platform  Nintendo
# 4     8               Wii Play      Wii  2006.0      Misc  Nintendo
#
#    Global_Sales  median  Averaged_Sales
# 0         82.74    7.23       11.443983
# 1         35.82    7.23        4.954357
# 2         33.00    7.23        4.564315
# 3         30.01    7.23        4.150761
# 4         29.02    7.23        4.013831

# %%
plt.figure(figsize=(20, 20))
sns.boxplot(data = dfNin, x = "Year", y = "Averaged_Sales", whis = 1.5, hue ="Platform")
# swarm plot to display the datapoints over the box plot
sns.stripplot(data = dfNin, x = "Year", y = "Averaged_Sales", color = "0.25")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Averaged_Sales'>

# %%
sns.pairplot(dfNin)

# %% [markdown]
# # Beginning of round 3 EAD with all listed datas:

# %%
def load_and_process_all(filePath):
    import pandas as pd
    import statistics as stsc
    dfClean = (
        pd.read_csv(filePath,
        usecols = ["Rank", "Name", "Publisher", "Platform", "Genre", "Global_Sales", "Year"]) # So far our only focus of work
        .sort_values(by= "Global_Sales", ascending = False) # Cash money check
        #.loc[lambda x: x["Year"] >= 2000] # Check for only recent games
        .dropna(axis = 0, thresh = 3) # Drop any NA values completely
        .loc[lambda x: x["Global_Sales"].between(5, 90.00)] # Remove the overkill outlier Wii sport saes at 80
        #Excessive low number sales mess up our median so we are removing it for now by specifying values between 5-90
        .reset_index(drop=True) # Reset index so we don't mess up orders
    )


    dfWii = (
        dfClean
        .loc[lambda x: x["Rank"] <= 3500] # Nothing ranked lower than 2500
        .assign(Averaged_Sales = lambda x: x["Global_Sales"]/stsc.median(dfClean["Global_Sales"])) #Putting the sales number over its median to try and mitigate issues from the outliers
        .sort_values(by= "Averaged_Sales", ascending = False) # Re-sort in case any vales got changed
        .reset_index(drop = True) # Order things nicely
    )
    return dfWii

# %%
dfAll = load_and_process_all("../../data/raw/Video_game_sales_db.csv")
dfAll
# Out:
#      Rank                                 Name Platform    Year         Genre  \
# 0       1                           Wii Sports      Wii  2006.0        Sports
# 1       2                    Super Mario Bros.      NES  1985.0      Platform
# 2       3                       Mario Kart Wii      Wii  2008.0        Racing
# 3       4                    Wii Sports Resort      Wii  2009.0        Sports
# 4       5             Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ..    ...                                  ...      ...     ...           ...
# 202   203               Tony Hawk's Pro Skater       PS  1999.0        Sports
# 203   204  Super Smash Bros. for Wii U and 3DS     WiiU  2014.0      Fighting
# 204   205                         Warzone 2100       PS  1999.0      Strategy
# 205   206                     Spyro the Dragon       PS  1998.0      Platform
# 206   207             Link's Crossbow Training      Wii  2007.0       Shooter
#
#                        Publisher  Global_Sales  Averaged_Sales
# 0                       Nintendo         82.74       11.443983
# 1                       Nintendo         40.24        5.565698
# 2                       Nintendo         35.82        4.954357
# 3                       Nintendo         33.00        4.564315
# 4                       Nintendo         31.37        4.338866
# ..                           ...           ...             ...
# 202                   Activision          5.02        0.694329
# 203                     Nintendo          5.02        0.694329
# 204            Eidos Interactive          5.01        0.692946
# 205  Sony Computer Entertainment          5.00        0.691563
# 206                     Nintendo          5.00        0.691563
#
# [207 rows x 8 columns]

# %%
# The global sales account for all regional sales so I am omitting the sales by region for this exploration
from scripts import load_and_process#from analysis.scripts import load_and_process
dfAllM = load_and_process.load_and_process_all("../../data/raw/Video_game_sales_db.csv")
dfWiiM= load_and_process.load_and_process_wii("../../data/raw/Video_game_sales_db.csv")
#Nintendo method currently not working even tho other modules are working
dfNinM = load_and_process.load_and_process_nintendo("../../data/raw/Video_game_sales_db.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-49aab307a121> in <module>
#       4 dfWiiM= load_and_process.load_and_process_wii("../../data/raw/Video_game_sales_db.csv")
#       5 #Nintendo method currently not working even tho other modules are working
# ----> 6 dfNinM = load_and_process.load_and_process_nintendo("../../data/raw/Video_game_sales_db.csv")
#
# AttributeError: module 'scripts.load_and_process' has no attribute 'load_and_process_nintendo'

# %%
dfAllM
# Out:
#      Rank                                 Name Platform    Year         Genre  \
# 0       1                           Wii Sports      Wii  2006.0        Sports
# 1       2                    Super Mario Bros.      NES  1985.0      Platform
# 2       3                       Mario Kart Wii      Wii  2008.0        Racing
# 3       4                    Wii Sports Resort      Wii  2009.0        Sports
# 4       5             Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ..    ...                                  ...      ...     ...           ...
# 202   203               Tony Hawk's Pro Skater       PS  1999.0        Sports
# 203   204  Super Smash Bros. for Wii U and 3DS     WiiU  2014.0      Fighting
# 204   205                         Warzone 2100       PS  1999.0      Strategy
# 205   206                     Spyro the Dragon       PS  1998.0      Platform
# 206   207             Link's Crossbow Training      Wii  2007.0       Shooter
#
#                        Publisher  Global_Sales  Averaged_Sales
# 0                       Nintendo         82.74       11.443983
# 1                       Nintendo         40.24        5.565698
# 2                       Nintendo         35.82        4.954357
# 3                       Nintendo         33.00        4.564315
# 4                       Nintendo         31.37        4.338866
# ..                           ...           ...             ...
# 202                   Activision          5.02        0.694329
# 203                     Nintendo          5.02        0.694329
# 204            Eidos Interactive          5.01        0.692946
# 205  Sony Computer Entertainment          5.00        0.691563
# 206                     Nintendo          5.00        0.691563
#
# [207 rows x 8 columns]

# %%
dfWiiM
# Out:
#     Rank                                    Name Platform    Year     Genre  \
# 0      1                              Wii Sports      Wii  2006.0    Sports
# 1      3                          Mario Kart Wii      Wii  2008.0    Racing
# 2      4                       Wii Sports Resort      Wii  2009.0    Sports
# 3      8                                Wii Play      Wii  2006.0      Misc
# 4      9               New Super Mario Bros. Wii      Wii  2009.0  Platform
# 5     14                                 Wii Fit      Wii  2007.0    Sports
# 6     15                            Wii Fit Plus      Wii  2009.0    Sports
# 7     40                 Super Smash Bros. Brawl      Wii  2008.0  Fighting
# 8     49                      Super Mario Galaxy      Wii  2007.0  Platform
# 9     61                            Just Dance 3      Wii  2011.0      Misc
# 10    69                            Just Dance 2      Wii  2010.0      Misc
# 11    79                               Wii Party      Wii  2010.0      Misc
# 12    81                           Mario Party 8      Wii  2007.0      Misc
# 13    86      Mario & Sonic at the Olympic Games      Wii  2007.0    Sports
# 14    92                    Super Mario Galaxy 2      Wii  2010.0  Platform
# 15   101  The Legend of Zelda: Twilight Princess      Wii  2006.0    Action
# 16   103                              Just Dance      Wii  2009.0      Misc
# 17   112                            Just Dance 4      Wii  2012.0      Misc
# 18   118                           Zumba Fitness      Wii  2010.0    Sports
# 19   126             Donkey Kong Country Returns      Wii  2010.0  Platform
# 20   151       LEGO Star Wars: The Complete Saga      Wii  2007.0    Action
# 21   207                Link's Crossbow Training      Wii  2007.0   Shooter
#
#     Global_Sales  Averaged_Sales
# 0          82.74       11.443983
# 1          35.82        4.954357
# 2          33.00        4.564315
# 3          29.02        4.013831
# 4          28.62        3.958506
# 5          22.72        3.142462
# 6          22.00        3.042877
# 7          13.04        1.803596
# 8          11.52        1.593361
