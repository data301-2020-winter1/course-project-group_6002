# %% [markdown]
# ## Research focus
#
# Suppose any continuous trends persist in the sale data, how does it change over time? If there are changes in the directions, we hope to identify it and visualize it.
#
# To support our quest of understanding if there are any continuous trends in sale data. We worked out some analysis on our datasets. Due to a small mishap, our analysis were done on two different datasets. Part 1 is performed on a dataset that collected data uptil 2016. In part 2, the analysis shifted to focus on the dataset with new game data up to 2019.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stsc

# %%
# The global sales account for all regional sales so I am omitting the sales by region for this exploration
from scripts import load_and_process#from analysis.scripts import load_and_process
dfAll = load_and_process.load_and_process_all("../../data/raw/Video_game_sales_db.csv")
dfAll
# Out:
#     Rank                            Name Platform    Year         Genre  \
# 0      1                      Wii Sports      Wii  2006.0        Sports
# 1      2               Super Mario Bros.      NES  1985.0      Platform
# 2      3                  Mario Kart Wii      Wii  2008.0        Racing
# 3      4               Wii Sports Resort      Wii  2009.0        Sports
# 4      5        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ..   ...                             ...      ...     ...           ...
# 70    71  Call of Duty 4: Modern Warfare     X360  2007.0       Shooter
# 71    72             Donkey Kong Country     SNES  1994.0      Platform
# 72    73                       Minecraft     X360  2013.0          Misc
# 73    74       Animal Crossing: New Leaf      3DS  2012.0    Simulation
# 74    75                  Mario Party DS       DS  2007.0          Misc
#
#                  Publisher  Global_Sales  Averaged_Sales
# 0                 Nintendo         82.74        6.147103
# 1                 Nintendo         40.24        2.989599
# 2                 Nintendo         35.82        2.661218
# 3                 Nintendo         33.00        2.451709
# 4                 Nintendo         31.37        2.330609
# ..                     ...           ...             ...
# 70              Activision          9.32        0.692422
# 71                Nintendo          9.30        0.690936
# 72  Microsoft Game Studios          9.20        0.683507
# 73                Nintendo          9.09        0.675334
# 74                Nintendo          9.02        0.670134
#
# [75 rows x 8 columns]

# %%
df2019G = dfAll.groupby(["Genre","Publisher", "Year", "Platform"]).sum()["Global_Sales"]
#df2019G
dfG = pd.DataFrame(df2019G)
dfG.head(25)
# Out:
#                                                   Global_Sales
# Genre     Publisher              Year   Platform
# Action    Nintendo               2009.0 DS               11.90
#           Take-Two Interactive   2001.0 PS2              13.10
#                                  2002.0 PS2              16.15
#                                  2004.0 PS2              20.81
#                                  2008.0 PS3              10.57
#                                         X360             11.02
#                                  2013.0 PS3              21.40
#                                         X360             16.38
#                                  2014.0 PS4              11.98
# Adventure Nintendo               1992.0 GB               11.18
# Fighting  Nintendo               2008.0 Wii              13.04
# Misc      Microsoft Game Studios 2010.0 X360             21.82
#                                  2013.0 X360              9.20
#           Nintendo               2005.0 DS               20.22
#                                  2006.0 Wii              29.02
#                                  2007.0 DS                9.02
#           Ubisoft                2010.0 Wii               9.52
#                                  2011.0 Wii              10.26
# Platform  Nintendo               1985.0 NES              40.24
#                                  1988.0 NES              17.28
#                                  1989.0 GB               18.14
#                                  1990.0 SNES             20.61
#                                  1993.0 SNES             10.55
#                                  1994.0 SNES              9.30
#                                  1996.0 N64              11.89

# %%
# Analyzing the sales trend with an overview of sales through the years done via GroupBy and plot functions

dfG.plot(figsize=(12,12))
plt.xticks(rotation=30) 
plt.show()
